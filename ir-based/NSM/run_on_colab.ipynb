# %%
import os
os.chdir('WSDM2021_NSM')
# !pwd

# 将sh文件中的路径更改成下面的格式
# !ls /content/drive/MyDrive/datasets/
# !./run_webqsp.sh
# Out:
# /Users/xchange/PycharmProjects/NLP_KBQA/ir-based/NSM
# /Users/xchange/PycharmProjects/NLP_KBQA/ir-based/NSM/NSM

# %%
# !git clone https://github.com/RichardHGL/WSDM2021_NSM.git
# Out:
# Cloning into 'WSDM2021_NSM'...
# remote: Enumerating objects: 180, done.
# remote: Counting objects: 100% (180/180), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 180 (delta 70), reused 93 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (180/180), 4.57 MiB | 16.48 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
# !mkdir WSDM2021_NSM/checkpoint
# !mkdir WSDM2021_NSM/dataset
# Out:
# /Users/xchange/PycharmProjects/NLP_KBQA/ir-based/NSM

# %% [markdown]
# 需要先将数据集存储到同账号的Google Drive上，再运行下面的程序。

# %%
from google.colab import drive
drive.mount('/content/drive')

# import os

# 如果数据没有解压，则执行这段代码一次，否则忽略。
# dataset_path = '/content/drive/MyDrive/datasets/'
# for file in os.listdir(dataset_path):
#     if file.endswith('.tgz'):
#         file_path = os.path.join(dataset_path, file)
#         !tar -xvzf {file_path} -C {dataset_path}
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#       4 # import os
#       5
#       6 # 如果数据没有解压，则执行这段代码一次，否则忽略。
#    (...)
#      10 #         file_path = os.path.join(dataset_path, file)
#      11 #         !tar -xvzf {file_path} -C {dataset_path}
#
# ModuleNotFoundError: No module named 'google'

# %%
import os
os.chdir('WSDM2021_NSM')
# !pwd
# Out:
# /content/WSDM2021_NSM

# %%
# !./run_webqsp.sh
# Out:
# 2025-01-14 17:23:49,489 - root - INFO - PARAMETER----------
# 2025-01-14 17:23:49,490 - root - INFO - BATCH_SIZE=20
# 2025-01-14 17:23:49,490 - root - INFO - CHAR2ID=chars.txt
# 2025-01-14 17:23:49,490 - root - INFO - CHECKPOINT_DIR=checkpoint/pretrain/
# 2025-01-14 17:23:49,490 - root - INFO - DATA_FOLDER=/content/drive/MyDrive/datasets/webqsp/
# 2025-01-14 17:23:49,490 - root - INFO - DECAY_RATE=0.0
# 2025-01-14 17:23:49,490 - root - INFO - ENCODE_TYPE=True
# 2025-01-14 17:23:49,490 - root - INFO - ENCODER_TYPE=lstm
# 2025-01-14 17:23:49,490 - root - INFO - ENTITY2ID=entities.txt
# 2025-01-14 17:23:49,490 - root - INFO - ENTITY_DIM=50
# 2025-01-14 17:23:49,490 - root - INFO - ENTITY_EMB_FILE=None
# 2025-01-14 17:23:49,490 - root - INFO - ENTITY_KGE_FILE=None
# 2025-01-14 17:23:49,490 - root - INFO - ENTROPY_WEIGHT=0.0
# 2025-01-14 17:23:49,490 - root - INFO - EPS=0.95
# 2025-01-14 17:23:49,490 - root - INFO - EVAL_EVERY=2
# ...

# %%
while True:
  # print('hello')
  pass
